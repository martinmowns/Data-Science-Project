# %% [markdown]
# <a href="https://colab.research.google.com/github/martinmowns/Data-Science-Project/blob/main/California_House_Pricing_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import Package
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as st
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_absolute_error , mean_squared_error , mean_absolute_percentage_error
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.neighbors import NearestNeighbors
from sklearn.linear_model import LinearRegression, Ridge, Lasso

# %%
df = pd.read_csv('housing.csv')

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df.tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND

# %%
df.shape
# Out:
# (20640, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
df['ocean_proximity'].value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        647.000000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20640.000000
# mean        206855.816909
# std         115395.615874
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264725.000000
# max         500001.000000

# %%
#Cek Missing Values
print('Missing Values pada Data :')
print(df.isnull().sum())
# Out:
# Missing Values pada Data :
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
#Handling Missing Value
print('=======================================\n')
print('Handling Missing Values variabel total_bedrooms pada Data :')
df['total_bedrooms'] = df['total_bedrooms'].fillna(df['total_bedrooms'].median())
df.isna().sum()
# Out:
# =======================================
#
# Handling Missing Values variabel total_bedrooms pada Data :
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
#Cek Outlier
sns.boxplot(df['median_house_value'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Define Q1 and Q3

Q1 = df['median_house_value'].quantile(0.25)
Q3 = df['median_house_value'].quantile(0.75)
IQR = Q3 - Q1
Lower_Whisker = Q1-(1.5*IQR)
Upper_Whisker = Q3+(1.5*IQR)
print(Upper_Whisker)
print(Lower_Whisker)
# Out:
# 482412.5
# -98087.5

# %%
df= df[(df['median_house_value']>Lower_Whisker) & (df['median_house_value']<Upper_Whisker)]
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [19569 rows x 10 columns]

# %%
sns.heatmap(df.isnull(), yticklabels = False, cbar = False, cmap = 'viridis')

# %% [markdown]
# ## **EDA**

# %%
sns.countplot(df['ocean_proximity'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(8,8))
colors = sns.color_palette('pastel')[0:5]
labels = ['NEAR BAY', '<1 OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND']
#create pie chart
plt.pie(df['ocean_proximity'].value_counts(), labels = labels, colors = colors, autopct='%.0f%%')
plt.title("Proporsi Ocean Proximility")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.barplot(x="ocean_proximity",y="total_rooms", data=df, order=df.sort_values('total_rooms',ascending = False).ocean_proximity.head(5))
plt.title("Jumlah Ruangan Berdasarkan Ocean Proximity")
plt.ylabel("total_rooms")
plt.xlabel("ocean_proximity")
plt.show()

# %%
sns.lineplot(x="households", y ="median_income",data=df)
plt.title("Pertumbuhan Income yang Didapatkan Berdasarkan Jumlah Total Rumah Tangga")
plt.show()

# %%
sns.lineplot(x="housing_median_age", y ="median_income",data=df)
plt.title("Pertumbuhan Income yang Didapatkan Berdasarkan Umur Rumah")
plt.show()

# %%
sns.scatterplot(data=df, x="population", y="median_house_value", hue="ocean_proximity", palette="rocket", alpha=0.4).set(
    title = "How does price of house change with population and ocean proxmity - PLOT 1",
    xlabel = "Population",
    ylabel = "House Price"
)
plt.show()

# %%
# Heatmap
fig = plt.figure(figsize=(12,12))
corr = df.corr()
sns.heatmap(corr, annot=True, square=True,)
plt.yticks(rotation=0)

plt.show()

# %%
df.corr().style.background_gradient().set_precision(2)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   """Entry point for launching an IPython kernel.
# <style type="text/css">
# #T_e7021_row0_col0, #T_e7021_row1_col1, #T_e7021_row2_col2, #T_e7021_row3_col3, #T_e7021_row4_col4, #T_e7021_row5_col5, #T_e7021_row6_col6, #T_e7021_row7_col7, #T_e7021_row8_col8 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_e7021_row0_col1, #T_e7021_row1_col0, #T_e7021_row1_col8, #T_e7021_row2_col3, #T_e7021_row2_col4, #T_e7021_row2_col5, #T_e7021_row2_col6, #T_e7021_row2_col7, #T_e7021_row3_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_e7021_row0_col2, #T_e7021_row4_col8 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_e7021_row0_col3 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_e7021_row0_col4 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_e7021_row0_col5, #T_e7021_row8_col4 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_e7021_row0_col6 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_e7021_row0_col7 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_e7021_row0_col8 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_e7021_row1_col2, #T_e7021_row7_col6 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_e7021_row1_col3 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_e7021_row1_col4 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_e7021_row1_col5 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_e7021_row1_col6, #T_e7021_row2_col8 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_e7021_row1_col7 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_e7021_row2_col0 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_e7021_row2_col1 {
#   background-color: #7bacd1;
#   color: #f1f1f1;
# }
# #T_e7021_row3_col0 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_e7021_row3_col1 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_e7021_row3_col4 {
#   background-color: #03466e;
#   color: #f1f1f1;
# }
# #T_e7021_row3_col5 {
#   background-color: #045585;
#   color: #f1f1f1;
# }
# #T_e7021_row3_col6 {
#   background-color: #034871;
#   color: #f1f1f1;
# }
# #T_e7021_row3_col7 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_e7021_row3_col8 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_e7021_row4_col0 {
#   background-color: #6ba5cd;
#   color: #f1f1f1;
# }
# #T_e7021_row4_col1, #T_e7021_row6_col1 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_e7021_row4_col2 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_e7021_row4_col3 {
#   background-color: #03456c;
#   color: #f1f1f1;
# }
# #T_e7021_row4_col5, #T_e7021_row5_col4 {
#   background-color: #045280;
#   color: #f1f1f1;
# }
# #T_e7021_row4_col6, #T_e7021_row6_col4 {
#   background-color: #023d60;
#   color: #f1f1f1;
# }
# #T_e7021_row4_col7 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_e7021_row5_col0 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
# }
# #T_e7021_row5_col1 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_e7021_row5_col2 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_e7021_row5_col3 {
#   background-color: #045483;
#   color: #f1f1f1;
# }
# #T_e7021_row5_col6, #T_e7021_row6_col5 {
#   background-color: #034a74;
#   color: #f1f1f1;
# }
# #T_e7021_row5_col7 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_e7021_row5_col8 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_e7021_row6_col0 {
#   background-color: #6fa7ce;
#   color: #f1f1f1;
# }
# #T_e7021_row6_col2 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_e7021_row6_col3 {
#   background-color: #03476f;
#   color: #f1f1f1;
# }
# #T_e7021_row6_col7 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_e7021_row6_col8 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_e7021_row7_col0 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_e7021_row7_col1 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_e7021_row7_col2 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_e7021_row7_col3 {
#   background-color: #8eb3d5;
#   color: #000000;
# }
# #T_e7021_row7_col4, #T_e7021_row7_col5 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T_e7021_row7_col8 {
#   background-color: #1c7fb8;
#   color: #f1f1f1;
# }
# #T_e7021_row8_col0 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_e7021_row8_col1 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_e7021_row8_col2, #T_e7021_row8_col6 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_e7021_row8_col3 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_e7021_row8_col5 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_e7021_row8_col7 {
#   background-color: #187cb6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e7021_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >longitude</th>
#       <th class="col_heading level0 col1" >latitude</th>
#       <th class="col_heading level0 col2" >housing_median_age</th>
#       <th class="col_heading level0 col3" >total_rooms</th>
#       <th class="col_heading level0 col4" >total_bedrooms</th>
#       <th class="col_heading level0 col5" >population</th>
#       <th class="col_heading level0 col6" >households</th>
#       <th class="col_heading level0 col7" >median_income</th>
#       <th class="col_heading level0 col8" >median_house_value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e7021_level0_row0" class="row_heading level0 row0" >longitude</th>
#       <td id="T_e7021_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_e7021_row0_col1" class="data row0 col1" >-0.92</td>
#       <td id="T_e7021_row0_col2" class="data row0 col2" >-0.10</td>
#       <td id="T_e7021_row0_col3" class="data row0 col3" >0.04</td>
#       <td id="T_e7021_row0_col4" class="data row0 col4" >0.07</td>
#       <td id="T_e7021_row0_col5" class="data row0 col5" >0.10</td>
#       <td id="T_e7021_row0_col6" class="data row0 col6" >0.06</td>
#       <td id="T_e7021_row0_col7" class="data row0 col7" >-0.01</td>
#       <td id="T_e7021_row0_col8" class="data row0 col8" >-0.05</td>
#     </tr>
#     <tr>
#       <th id="T_e7021_level0_row1" class="row_heading level0 row1" >latitude</th>
#       <td id="T_e7021_row1_col0" class="data row1 col0" >-0.92</td>
#       <td id="T_e7021_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_e7021_row1_col2" class="data row1 col2" >0.01</td>
#       <td id="T_e7021_row1_col3" class="data row1 col3" >-0.03</td>
#       <td id="T_e7021_row1_col4" class="data row1 col4" >-0.07</td>
#       <td id="T_e7021_row1_col5" class="data row1 col5" >-0.11</td>
#       <td id="T_e7021_row1_col6" class="data row1 col6" >-0.07</td>
#       <td id="T_e7021_row1_col7" class="data row1 col7" >-0.08</td>
#       <td id="T_e7021_row1_col8" class="data row1 col8" >-0.15</td>
#     </tr>
#     <tr>
#       <th id="T_e7021_level0_row2" class="row_heading level0 row2" >housing_median_age</th>
#       <td id="T_e7021_row2_col0" class="data row2 col0" >-0.10</td>
#       <td id="T_e7021_row2_col1" class="data row2 col1" >0.01</td>
#       <td id="T_e7021_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_e7021_row2_col3" class="data row2 col3" >-0.37</td>
#       <td id="T_e7021_row2_col4" class="data row2 col4" >-0.33</td>
#       <td id="T_e7021_row2_col5" class="data row2 col5" >-0.29</td>
#       <td id="T_e7021_row2_col6" class="data row2 col6" >-0.31</td>
#       <td id="T_e7021_row2_col7" class="data row2 col7" >-0.20</td>
#       <td id="T_e7021_row2_col8" class="data row2 col8" >0.06</td>
#     </tr>
#     <tr>
#       <th id="T_e7021_level0_row3" class="row_heading level0 row3" >total_rooms</th>
#       <td id="T_e7021_row3_col0" class="data row3 col0" >0.04</td>
#       <td id="T_e7021_row3_col1" class="data row3 col1" >-0.03</td>
#       <td id="T_e7021_row3_col2" class="data row3 col2" >-0.37</td>
#       <td id="T_e7021_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_e7021_row3_col4" class="data row3 col4" >0.93</td>
#       <td id="T_e7021_row3_col5" class="data row3 col5" >0.86</td>
#       <td id="T_e7021_row3_col6" class="data row3 col6" >0.92</td>
#       <td id="T_e7021_row3_col7" class="data row3 col7" >0.23</td>
#       <td id="T_e7021_row3_col8" class="data row3 col8" >0.15</td>
#     </tr>
#     <tr>
#       <th id="T_e7021_level0_row4" class="row_heading

# %% [markdown]
# # **Feature Engineering**

# %% [markdown]
# One Hot Encoding

# %%
le_ocean_pro = LabelEncoder()
df["ocean_proximity"] =le_ocean_pro.fit_transform(df["ocean_proximity"])
df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value  ocean_proximity
# 0       322.0       126.0         8.3252            452600.0                3
# 1      2401.0      1138.0         8.3014            358500.0                3
# 2       496.0       177.0         7.2574            352100.0                3
# 3       558.0       219.0         5.6431            341300.0                3
# 4       565.0       259.0         3.8462            342200.0                3

# %%
df['ocean_proximity'].value_counts()
# Out:
# 0    8552
# 1    6519
# 4    2419
# 3    2074
# 2       5
# Name: ocean_proximity, dtype: int64

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#        ocean_proximity
# 0                    3
# 1                    3
# 2                    3
# 3                    3
# 4                    3
# ...                ...
# 20635                1
# 20636                1
# 20637                1
# 20638                1
# 20639                1
#
# [19569 rows x 10 columns]

# %% [markdown]
# ## **Split Data**

# %%
#Pembagian Data

#Target
y=df['median_house_value']

#Feature
X=df.drop(['median_house_value'],axis=1)

# %%
 y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 19569, dtype: float64

# %%
X
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  ocean_proximity
# 0           322.0       126.0         8.3252                3
# 1          2401.0      1138.0         8.3014                3
# 2           496.0       177.0         7.2574                3
# 3           558.0       219.0         5.6431                3
# 4           565.0       259.0         3.8462                3
# ...           ...         ...            ...              ...
# 20635       845.0       330.0         1.5603                1
# 20636       356.0       114.0         2.5568                1
# 20637      1007.0       433.0         1.7000                1
# 20638       741.0       349.0         1.8672                1
# 20639      1387.0       530.0         2.3886                1
#
# [19569 rows x 9 columns]

# %%
#Function Random Forest
def forest(df):
  #Split Data
  train_X, test_X, train_y, test_y = train_test_split(X, y, test_size=0.25, random_state=43)

  #Model Random Forest

  #create the model
  rf=RandomForestRegressor()

  #fit the model
  rf_fit = rf.fit(train_X,train_y)

  #prediction value
  rf_predict = rf.predict(test_X)

  #score random forest
  rf_score = rf.score(train_X, train_y), rf.score(test_X, test_y)
  return rf_predict, rf_score, test_y

# %%
rf_predict, rf_score, test_y = forest(df)

# %%
print("Random Forest Score: {}".format(rf_score))
# Out:
# Random Forest Score: (0.9700720356278123, 0.7942265067475499)

# %%
#Function Linear Regression
def linear(df):
  #Split Data
  train_X, test_X, train_y, test_y = train_test_split(X, y, test_size=0.25, random_state=43)

  #Model Random Forest

  #create the model
  lr = LinearRegression()

  #fit the model
  lr_fit = lr.fit(train_X,train_y)

  #prediction value
  lr_predict = lr.predict(test_X)

  #score random forest
  lr_score = lr.score(train_X, train_y), lr.score(test_X, test_y)
  return lr_predict, lr_score, test_y

# %%
lr_predict, lr_score, test_y = linear(df)

# %%
print("Linear Regression Score: {}".format(lr_score))
# Out:
# Linear Regression Score: (0.6011240629891184, 0.6002390063667927)

# %%
#Function Ridge Regression
def ridge(df):
  #Split Data
  train_X, test_X, train_y, test_y = train_test_split(X, y, test_size=0.25, random_state=43)

  #Model Random Forest

  #create the model
  r = Ridge()

  #fit the model
  r_fit = r.fit(train_X,train_y)

  #prediction value
  r_predict = r.predict(test_X)

  #score random forest
  r_score = r.score(train_X, train_y), r.score(test_X, test_y)
  return r_predict, r_score, test_y

# %%
r_predict, r_score, test_y = ridge(df)

# %%
print("Ridge Regression Score: {}".format(r_score))
# Out:
# Ridge Regression Score: (0.6011240571748427, 0.6002400514228254)

# %%
compare_rf = pd.DataFrame({"Actual Data": test_y, "Predicted Data": rf_predict})
compare_linear = pd.DataFrame({"Actual Data": test_y, "Predicted Data": lr_predict})
print("-------------------------------------")
print("---------Random Forest Regression----------")
print(compare_rf.head(10))
print("-------------------------------------")
print("---------------Linear Regression------------------")
print(compare_linear.head(10))
# Out:
# -------------------------------------
# ---------Random Forest Regression----------
#        Actual Data  Predicted Data
# 19660      93100.0        128098.0
# 16441     101800.0        117259.0
# 17527     212500.0        218611.0
# 652       188900.0        180110.0
# 11856      82500.0         91328.0
# 5778      178600.0        224817.0
# 9881      162200.0        163103.0
# 7916      200800.0        195891.0
# 18477     321700.0        257309.0
# 10492     294300.0        294564.0
# -------------------------------------
# ---------------Linear Regression------------------
#        Actual Data  Predicted Data
# 19660      93100.0    74266.932569
# 16441     101800.0   153825.272470
# 17527     212500.0   152639.602732
# 652       188900.0   207340.483740
# 11856      82500.0    14287.757944
# 5778      178600.0   191319.645475
# 9881      162200.0   216696.289593
# 7916      200800.0   204228.444791
# 18477     321700.0   275735.400346
# 10492     294300.0   293077.600596

# %%
def actual_pred_plot(df, title):
    plt.figure(figsize =(14,6))
    df = df.reset_index()
    df = df.drop(["index"], axis=1)
    plt.plot(df[:50])
    plt.legend(["Actual", "Predicted"])
    plt.title(title)
    plt.show()

# %%
actual_pred_plot(compare_rf, "Random Forest Regression")

# %%
actual_pred_plot(compare_linear, "Linear Regression")

# %%
def models_evaluation(df, model_name):
    print("-------------------------------")
    print(model_name)
    print("R-Squared:", r2_score(df["Actual Data"], df["Predicted Data"]))
    print("MAE:", mean_absolute_error(df["Actual Data"], df["Predicted Data"]))
    print("MSE:", mean_squared_error(df["Actual Data"], df["Predicted Data"]))
    print("MAE%:", mean_absolute_percentage_error(df["Actual Data"], df["Predicted Data"]))
    print("-------------------------------")

# %%
models_evaluation(compare_rf, "Random Forest Regression")
# Out:
# -------------------------------
# Random Forest Regression
# R-Squared: 0.7942265067475499
# MAE: 28803.712382996117
# MSE: 1853650042.1827898
# MAE%: 0.17305515788648118
# -------------------------------

# %%
models_evaluation(compare_linear, "Linear Regression")
# Out:
# -------------------------------
# Linear Regression
# R-Squared: 0.6002390063667927
# MAE: 44618.30944440582
# MSE: 3601129431.195121
# MAE%: 0.2882988573087535
# -------------------------------

# %% [markdown]
# ## **BATAS SUCI**

# %%
#Pengujian
forest(X,y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-4957a63c3b68> in <module>()
#       1 #Pengujian
# ----> 2 forest(X,y)
#
# TypeError: forest() takes 1 positional argument but 2 were given

# %%
scaler = StandardScaler()
df_num = df.drop(['ocean_proximity'], axis = 1)
scaler.fit(df_num)
scaled_features = scaler.transform(df_num)
df_scaled = pd.DataFrame(scaled_features,columns = df_num.columns)
df_scaled.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0  -1.329808  1.034817            1.011986    -0.796925       -0.974358
# 1  -1.324823  1.025518           -0.588340     2.051432        1.348479
# 2  -1.334794  1.020869            1.892166    -0.528074       -0.829330
# 3  -1.339780  1.020869            1.892166    -0.616470       -0.722341
# 4  -1.339780  1.020869            1.892166    -0.454792       -0.615353
#
#    population  households  median_income  median_house_value
# 0   -0.978870   -0.979155       2.990995            2.742648
# 1    0.836879    1.660479       2.975718            1.756648
# 2   -0.826903   -0.846130       2.305580            1.689588
# 3   -0.772754   -0.736580       1.269368            1.576423
# 4   -0.766640   -0.632247       0.115947            1.585853

# %%
#Model Evaluation
rf_mae = mean_absolute_error(rf_predict, test_y)
print("MAE for Random Forest Model: {}".format(rf_mae)
rf_R2 = r2_score(rf_predict, test_y)
print("R2 for Random Forest Model: {}".format(rf_R2)
rf_mse = mean_squared_error(rf_predict, test_y)
print("MSE for Random Forest Model: {}".format(rf_mse)
rf_mae_prcn = mean_absolute_percentage_error(rf_predict, test_y)
print("MAE% for Random Forest Model: {}".format(rf_mae_prcn)

# %%
#Transformasi variabel kategori menjadi numerik dengan Encode
new_category=["ocean_proximity"]

df_category = df[new_category]
df_category.head()
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

df_cat_encode= df_category.copy()
for col in df_cat_encode.select_dtypes(include='O').columns:
    df_cat_encode[col]=le.fit_transform(df_cat_encode[col])
df_cat_encode
# Out:
#        ocean_proximity
# 0                    3
# 1                    3
# 2                    3
# 3                    3
# 4                    3
# ...                ...
# 20635                1
# 20636                1
# 20637                1
# 20638                1
# 20639                1
#
# [19569 rows x 1 columns]

# %%
df_cat_encode.value_counts()
# Out:
# ocean_proximity
# 0                  8552
# 1                  6519
# 4                  2419
# 3                  2074
# 2                     5
# dtype: int64

# %%
df_new=df_scaled.join(df_cat_encode)
df_new.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0  -1.329808  1.034817            1.011986    -0.796925       -0.974358
# 1  -1.324823  1.025518           -0.588340     2.051432        1.348479
# 2  -1.334794  1.020869            1.892166    -0.528074       -0.829330
# 3  -1.339780  1.020869            1.892166    -0.616470       -0.722341
# 4  -1.339780  1.020869            1.892166    -0.454792       -0.615353
#
#    population  households  median_income  median_house_value  ocean_proximity
# 0   -0.978870   -0.979155       2.990995            2.742648              3.0
# 1    0.836879    1.660479       2.975718            1.756648              3.0
# 2   -0.826903   -0.846130       2.305580            1.689588              3.0
# 3   -0.772754   -0.736580       1.269368            1.576423              3.0
# 4   -0.766640   -0.632247       0.115947            1.585853              3.0

# %%
f = plt.figure(figsize=(12,4))
f.add_subplot(1,2,1)
sns.countplot(df['total_bedrooms'])
f.add_subplot(1,2,2)
plt.boxplot(df['total_bedrooms'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
f = plt.figure(figsize=(12,4))
f.add_subplot(1,2,1)
sns.countplot(df['total_rooms'])
f.add_subplot(1,2,2)
plt.boxplot(df['total_rooms'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
f = plt.figure(figsize=(12,4))
f.add_subplot(1,2,1)
df['population'].plot(kind='kde')
f.add_subplot(1,2,2)
plt.boxplot(df['population'])
plt.show()

# %%
f = plt.figure(figsize=(12,4))
f.add_subplot(1,2,1)
sns.countplot(df['households'])
f.add_subplot(1,2,2)
plt.boxplot(df['households'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
f = plt.figure(figsize=(20,8))
f.add_subplot(1,2,1)
sns.countplot(df['housing_median_age'])
f.add_subplot(1,2,2)
plt.boxplot(df['housing_median_age'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
f = plt.figure(figsize=(20,8))
f.add_subplot(1,2,1)
sns.countplot(df['median_income'])
f.add_subplot(1,2,2)
plt.boxplot(df['median_income'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(10,8))
sns.pairplot(data=df, x_vars=['total_bedrooms', 'total_rooms', 'population', 'households', 'housing_median_age', 'median_income', 'ocean_proximity'], y_vars=['median_house_value'], size=5, aspect=0.75)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
